# %%
import pandas as pd
import numpy as np
import re
import tweepy
import json
from textblob import TextBlob
pd.set_option('display.max_colwidth', 280)
import time
from datetime import timedelta
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
vader = SentimentIntensityAnalyzer()
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob
nlp = spacy.load('en_core_web_sm')
# nlp.add_pipe('spacytextblob')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Intel PC
# [nltk_data]     G5900\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
vader.polarity_scores('I am great!')
# Out:
# {'neg': 0.0, 'neu': 0.185, 'pos': 0.815, 'compound': 0.6588}

# %%
eng_twits = pd.read_csv('eng_twits.csv')
eng_twits['tweet_id'] = eng_twits['tweet_id'].apply(lambda x: x if pd.isnull(x) else str(x))
eng_twits['user_id'] = eng_twits['user_id'].apply(lambda x: x if pd.isnull(x) else str(x))

# %%
eng_twits.shape
# Out:
# (1450, 13)

# %%
def cleantxt(text):
    '''
    Creat a function wich will remove mentions, remove hashtag words, removing the # symbol
    removing RT, removing the hyper link and other unnecessary characters.
    '''
    text = re.sub(r'@[A-Za-z0-9]+', ' ', text) #remove mentions
    text = re.sub(r"#(\w+)", ' ', text) #remove hashtag words
    text = re.sub(r'#', ' ', text) #removing the # symbol
    text = re.sub(r'RT[\s]+', ' ', text) #removing RT
    text = re.sub(r'https?:\/\/\S+', ' ', text) #removing the hyper link
    text = text.replace('\n', ' ')
    text = text.replace('&amp;', ' ')
    text = text.replace('&gt;', ' ')
    text = text.replace('_', ' ')
    text = text.strip()
#     text = text.lower()
    return text

def remove_emojis(data):
    '''
    Remove alla emoticons, flags, symbols and other characters.
    '''
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

def polarity(txt):
    '''
    Compute from Textblob text's polarity.
    '''
    twit_polarity = TextBlob(txt).sentiment.polarity
    return twit_polarity

def subjectivity(txt):
    '''
    Compute from Textblob text's subjectivity.
    '''
    twit_subjectivity = TextBlob(txt).sentiment.subjectivity
    return twit_subjectivity

def polarity_kind(num):
    '''
    Distinguish tweets in Positives, Neutrals and Negatives from Textblob's polarity.
    '''
    if num > 0.15:
        polarity_kind = 'Positive'
    elif num < 0:
        polarity_kind = 'Negative'
    else:
        polarity_kind = 'Neutral'
    return polarity_kind

def vader_polarity(txt):
    '''
    Compute from Vader text's polarity.
    '''
    vader_polarity = vader.polarity_scores(txt)['compound']
    return vader_polarity

def vader_polarity_kind(num):
    '''
    Distinguish tweets in Positives, Neutrals and Negatives from Vader's polarity.
    '''
    if num > 0.15:
        vader_polarity_kind = 'Positive'
    elif num < -0.15:
        vader_polarity_kind = 'Negative'
    else:
        vader_polarity_kind = 'Neutral'
    
    return vader_polarity_kind

# %%
eng_twits['cleaned_tweets'] = eng_twits['tweets'].apply(lambda x: x if pd.isnull(x) else cleantxt(x))
eng_twits['noemojis_tweets'] = eng_twits['cleaned_tweets'].apply(lambda x: x if pd.isnull(x) else remove_emojis(x))
eng_twits['twits_polarity'] = eng_twits['noemojis_tweets'].apply(lambda x: x if pd.isnull(x) else polarity(x))
eng_twits['twits_subjectivity'] = eng_twits['noemojis_tweets'].apply(lambda x: x if pd.isnull(x) else subjectivity(x))
eng_twits['polarity_kinds'] = eng_twits['twits_polarity'].apply(lambda x: x if pd.isnull(x) else polarity_kind(x))
eng_twits['twits_vader_polarity'] = eng_twits['noemojis_tweets'].apply(lambda x: x if pd.isnull(x) else vader_polarity(x))
eng_twits['vader_polarity_kinds'] = eng_twits['twits_vader_polarity'].apply(lambda x: x if pd.isnull(x) else vader_polarity_kind(x))

# %%
eng_twits[eng_twits['polarity_kinds'] == 'Positive'][['noemojis_tweets','twits_polarity', 'twits_subjectivity', 'polarity_kinds']].head(50)
# Out:
#                                                                                                                                                                                                                                             noemojis_tweets  \
# 1                                                                                                                                                                          I'm just gonna leave this here. Evacuation of  . Straight out of a horror movie.
# 10                                                                                                     She ain't a famous influencer nor a tiktok star. Her name's Katerina Ioannidou   she's a volunteer forest firefighter.                  Marios Lolos
# 11                               In Varimpompi, Greece, citizens are rounding up even at this time at night to help deliver food, drinks, and other important stuff to deliver to firefighters and fire-stricken citizens in Malakasa, Evoia and many more.
# 12                                                                                                                                                                                             In case you don’t know what’s happening in Greece right now:
# 14                               In Varimpompi, Greece, citizens are rounding up even at this time at night to help deliver food, drinks, and other important stuff to deliver to firefighters and fire-stricken citizens in Malakasa, Evoia and many more.
# 15                               In Varimpompi, Greece, citizens are rounding up even at this time at night to help deliver food, drinks, and other important stuff to deliver to firefighters and fire-stricken citizens in Malakasa, Evoia and many more.
# 16                                                                                                                             This morning’s satellite view of smoke and fires across   and  . Red areas show heat detected by satellite     More images →
# 17                               In Varimpompi, Greece, citizens are rounding up even at this time at night to help deliver food, drinks, and other important stuff to deliver to firefighters and fire-stricken citizens in Malakasa, Evoia and many more.
# 18                               In Varimpompi, Greece, citizens are rounding up even at this time at night to help deliver food, drinks, and other important stuff to deliver to firefighters and fire-stricken citizens in Malakasa, Evoia and many more.
# 23                                                                                                                                                                                             In case you don’t know what’s happening in Greece right now:
# 29                               In Varimpompi, Greece, citizens are rounding up even at this time at night to help deliver food, drinks, and other important stuff to deliver to firefighters and fire-stricken citizens in Malakasa, Evoia and many more.
# 36                                                                                                                             This morning’s satellite view of smoke and fires across   and  . Red areas show heat detected by satellite     More images →
# 39                    Death toll from Greek wildfires rises to 2 as fight against blazes enters 11th day - On the island of Evia, more than 1,300 people were evacuated by boat during the night from the coastal village of Limni was surrounded by flames
# 55         0.250000            0.250000       Positive
# 62         0.500000            1.000000       Positive
# 67         0.466667            0.666667       Positive
# 71         0.285714            0.535714       Positive
# 74         0.300000            0.950000       Positive
# 80         0.500000            1.000000       Positive
# 81         0.500000            1.000000       Positive
# 82         0.500000            0.600000       Positive
# 84         0.500000            1.000000       Positive
# 87         0.500000            0.600000       Positive
# 90         0.500000            1.000000       Positive
# 92         0.616667            0.816667       Positive
# 93         0.616667            0.816667       Positive
# 94         0.466667            0.666667       Positive
# 101        0.616667            0.816667       Positive
# 106        0.500000            0.600000       Positive
# 115        0.500000            0.600000       Positive
# 117        0.500000            0.600000       Positive
# 123        0.466667            0.666667       Positive
# 137        0.285714            0.535714       Positive
# 139        0.300000            0.950000       Positive
# 144        0.285714            0.535714       Positive
# 145        0.300000            0.950000       Positive
# 147        0.300000            0.950000       Positive
# 148        0.300000            0.950000       Positive
# 154        0.300000            0.950000       Positive
# 162        0.285714            0.535714       Positive
# 163        0.300000            0.950000       Positive
# 179        0.500000            0.600000       Positive
# 180        0.285714            0.535714       Positive
# 184        0.261905            0.678571       Positive
# 190        0.500000            0.600000       Positive
# 191        0.500000            0.600000       Positive
# 192        0.466667            0.666667       Positive

# %%
.eng_twits[eng_twits.user_id.duplicated()]
# Out:
#                                                                                                                                         description  \
# 6                                                                                                                  I'm your hate when you want love
# 46                                                                                                                                              NaN
# 53                                                                                                                                              NaN
# 91           Εραστής της 7ης Τέχνης - Κυνηγώντας @chimeres & ταξιδεύοντας παλαιότερα σε: @sodeia_net @cinefreaks @SevenArt_gr\nΣυνεργάτης του @tvxs
# 102                                                                                                                             I'm a Captcha Robot
# ...                                                                                                                                             ...
# 1347                                                                                                                                            NaN
# 1352  Researching ethnic and geographical inequalities, migration and diversity @ManMetUni @U_Inequalities @OfficialUoM @MigFamNet @MigrantsSupport
# 1369                                                                                                                                            NaN
# 1389                                                                                                        Μετρίως μέτριος (και πάντα μετρημένος).
# 1440                                                                                                                    It is none of your business
#
#       followers  following  \
# 6          60.0      160.0
# 46        245.0      236.0
# 53        245.0      236.0
# 91       5717.0      166.0
# 102       325.0      324.0
# ...         ...        ...
# 1347        0.0       56.0
# 1352      277.0      281.0
# 1369       28.0       52.0
# 1389       30.0       45.0
# 1440      207.0      526.0
#
#                                                  hashtags  \
# 6     ['φωτια', 'PrayForGreece', 'wildfires', 'Πυρκαγια']
# 46                                                     []
# 53                                                     []
# 91                                ['Greece', 'Wildfires']
# 102                                                    []
# ...                                                   ...
# 1347        ['Eviaisland', 'Ιστιαια', 'opentv', 'Ευβοια']
# 1352                                           ['Greece']
# 1369                               ['Πυρκαγια', 'opentv']
# 1389                                           ['Greece']
# 1440                                         ['Πυρκαγια']
#
#                   location  \
# 6                      NaN
# 46    gr | 17 | they/them
# 53    gr | 17 | they/them
# 91         Athens - Greece
# 102    Antigua and Barbuda
# ...                    ...
# 1440                                                                                                                                                                                                                               Thank you Qatar 🙏🙏🙏
#
#       twits_polarity  twits_subjectivity polarity_kinds  twits_vader_polarity  \
# 6           0.000000                0.00        Neutral                0.5106
# 46         -0.055556                0.50        Neutral               -0.9160
# 53          0.133333                0.56        Neutral                0.6771
# 91          0.000000                0.00        Neutral                0.0000
# 102        -0.018750                0.35        Neutral                0.2714
# ...              ...                 ...            ...                   ...
# 1347        0.000000                0.00        Neutral               -0.7269
# 1352        0.100000                0.20        Neutral                0.2023
# 1369        0.000000                0.00        Neutral                0.0000
# 1389        0.100000                0.20        Neutral                0.2023
# 1440        0.000000                0.00        Neutral                0.3612
#
#      vader_polarity_kinds  \
# 6                Positive
# 46               Negative
# 53               Positive
# 91                Neutral
# 102              Positive
# ...                   ...
# 1347             Negative
# 1352             Positive
# 1369              Neutral
# 1389             Positive
# 1440             Positive
#
#                                                                                                                                                                                                                                        noemojis_tweets
# 6                                                                                                                                                                                                                                               HEROES
# 46                 Greece is burning but the Mitsotakis regime is no where. People outcry for help, immediate response, and quick measurements to put the fire out but no help, and no response. Sadly, everyone is out there and left to their fates!
# 53                                                                                                   this is the real greece. more than 140 active wildfires. people evacuating, animals getting burnt alive. greece isn’t only santorini and mykonos.
# 91                                                                      -   spread, causing mass evacuations. Thousands of tourists and residents have been evacuated from towns north of the Greek capital,  , as wildfires spread across the country
# 102   On the island of Euboea the fires are approaching the town of Istiaia where thousands of residents are trapped and can only escape through the sea, there is an urgent need for any sort of boats/ferries near the area to help evacuate people!
# ...                                                                                                                                                                                                                                                ...
# 1347                                                                                                                                                                     Blaze ravages   on sixth day of Greek wildfires  "Fiery destruction"  REUTERS
# 1352                                                                                   81 years old woman watches the wildfire reaching her house in the village of Gouves on Evia island,   on August 8, 2021.       Photo by Konstantinos Tsakalidis
# 1369                                                                                                                                                                                                            The monastery of Saint David in Evoia.
# 1389                                                                                   81 years old woman watches the wildfire reaching her house in the village of Gouves on Evia island,   on August 8, 2021.       Photo by Konstantinos Tsakalidis
# 1440                                                                                                                                                                                                                                  Thank you Qatar
#
# [175 rows x 20 columns]

# %%
#eng_twits[eng_twits['twits_vader_polarity']!=0].sort_values(['twits_polarity','retweetcount'], ascending=[True,False]).head()

# %%
eng_twits['polarity_kinds'].value_counts()
# Out:
# Neutral     780
# Positive    410
# Negative    178
# Name: polarity_kinds, dtype: int64

# %%
eng_twits['vader_polarity_kinds'].value_counts()
# Out:
# Positive    824
# Negative    286
# Neutral     258
# Name: vader_polarity_kinds, dtype: int64

# %%
eng_twits['twits_polarity'].mean()
# Out:
# 0.12970357522845583

# %%
eng_twits['twits_subjectivity'].mean()
# Out:
# 0.47136775904909645

# %%
eng_twits['twits_vader_polarity'].mean()
# Out:
# 0.2972186403508773

# %%
eng_twits.to_csv('eng_twits_analyzed.csv', index=False)

# %%
eng_twits_analyzed = pd.read_csv('eng_twits_analyzed.csv')
